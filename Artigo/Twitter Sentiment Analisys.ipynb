# %% [markdown]
# # Twitter Setiment Analysis

# %% [markdown]
# ### Imports

# %%
# Basic Imports
import tweepy
import pandas as pd     
import numpy as np 
import time
import os
import re

# Plotting and Visualization
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
# %matplotlib inline

# TextBlob Imports
from textblob import TextBlob
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier

# NLTK Imports
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

#MAP
from geopy.geocoders import Nominatim
import folium
from folium import plugins
from geopy.geocoders import Nominatim

# %% [markdown]
# ### Twitter Autentication Keys

# %%
#Keys for autentication
consumer_key=''
consumer_secret=''

access_token=''
access_token_secret=''

# %% [markdown]
# ### Twitter Autentication

# %%
#Autentication Methods
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# ### Searching for Tweets

# %%
#Searchin Twitter Timelines
tweets = []
info = []

for tweet in tweepy.Cursor(api.search,
                           q="lula bolsonaro",
                           tweet_mode='extended',
                           rpp=100,
                           result_type="popular",
                           include_entities=True,
                           lang="pt").items(1500):
    if 'retweeted_status' in dir(tweet):
        aux=tweet.retweeted_status.full_text
    else:
        aux=tweet.full_text
        
    newtweet = aux.replace("\n", " ")
   
    tweets.append(newtweet)
    info.append(tweet)
    
    file = open("lula-bolsonaro.txt", "a", -1, "utf-8")
    file.write(newtweet+'\n')
    file.close()
    
    time.sleep(0.5)

# %% [markdown]
# ### Creating the dataframe

# %%
#Construction of the dataframe
tweets_df = pd.DataFrame(tweets, columns=['Tweets']) 

tweets_df['len']  = np.array([len(tweet) for tweet in tweets])
tweets_df['ID']   = np.array([tweet.id for tweet in info])
tweets_df['Date'] = np.array([tweet.created_at for tweet in info])
tweets_df['Source'] = np.array([tweet.source for tweet in info])
tweets_df['Likes']  = np.array([tweet.favorite_count for tweet in info])
tweets_df['RTs']    = np.array([tweet.retweet_count for tweet in info])
tweets_df['User Location']    = np.array([tweet.user.location for tweet in info])
tweets_df['Geo']    = np.array([tweet.geo for tweet in info])
tweets_df['Coordinates']    = np.array([tweet.coordinates for tweet in info])

tweets_df.to_csv("lula-bolsonaro.csv")

# %%
tweets_df.head()
# Out:
#                                               Tweets  len  \
# 0  A mudança do país que culminou com eleição de ...  274
# 1  VÍDEO: “Quem votou no Bolsonaro que cobre ele....  106
# 2  Com Lula, o Brasil reassumiu sua soberania e p...  181
# 3  De 2003 até o golpe de 2016, o Brasil foi prot...  185
# 4  Quem mandou Adélio esfaquear Bolsonaro? Ele ag...  116
#
#                     ID                Date               Source  Likes  RTs  \
# 0  1076667402346221568 2018-12-23 02:34:46   Twitter for iPhone   3855  702
# 1  1076766217220882433 2018-12-23 09:07:26   Twitter Web Client    575  181
# 2  1076891824684453888 2018-12-23 17:26:33   Twitter Web Client    866  229
# 3  1076877593738133504 2018-12-23 16:30:00            TweetDeck    474  181
# 4  1076477470453522432 2018-12-22 14:00:03  Twitter for Android    363   99
#
#        User Location   Geo Coordinates
# 0      Paraná/Brasil  None        None
# 1  Sao Paulo, Brazil  None        None
# ...

# %% [markdown]
# ### Top Tweets

# %%
# Top Searched Tweets
fav_max = np.max(tweets_df['Likes'])
rt_max  = np.max(tweets_df['RTs'])

fav = tweets_df[tweets_df.Likes == fav_max].index[0]
rt  = tweets_df[tweets_df.RTs == rt_max].index[0]

# Max FAVs:
print("O tweet com mais curtidas é: \n{}".format(tweets_df['Tweets'][fav]))
print("Número de curtidas: {}".format(fav_max))
print("\n")
# Max RTs:
print("O tweet com mais retweet é: \n{}".format(tweets_df['Tweets'][rt]))
print("Número de retweets: {}".format(rt_max))
# Out:
# O tweet com mais curtidas é:
# Lula livre não é bom pra ninguém. Lula vai continuar sendo o condenado desacreditado, preso em casa.  Bolsonaro ganha uma pauta nova que nao é o Queiroz. MBL ja tá alvoroçando o país pra protestar e capitalizar o antipetismo. STF perde os pontinhos que tinha com a opinião pública
# Número de curtidas: 11901
#
#
# O tweet com mais retweet é:
# Sabem quem não apareceu pra depor hoje conforme marcado? Ele mesmo, o assessor-amigão do clã Bolsonaro, o Queiroz! Alegou uma "crise inesperada de saúde".  Mas os que "não têm corrupto de estimação" estão caladinhos. Ou melhor: estão, como de costume, gritando sobre o Lula.
# Número de retweets: 2323

# %% [markdown]
# ### Source of Tweets

# %%
#Source of the Tweets
sources = []
for source in tweets_df['Source']:
    if source not in sources:
        sources.append(source)

percent = np.zeros(len(sources))

for source in tweets_df['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

# %%
newDF = pd.DataFrame({
 'source':percent,
}, index=sources)

sources_sorted = newDF.sort_values('source',ascending=False)
ax = sources_sorted.source.plot(kind='barh',color='#002060')
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# %% [markdown]
# # ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

# %% [markdown]
# # COMECEI AQUI

# %%
df = pd.read_json('100k_origin_teste.json',convert_dates=False,lines=True,chunksize=1000)

# %%
text = pd.Series(name = 'ID')
loc = pd.Series(name = 'user')
dts = pd.Series(name = 'data')
for dtf in df:
    text=text.append(dtf['text'])
    dts=dts.append(dtf['created_at'])
    loc=loc.append(dtf['user'])
# Out:
# C:\Users\vicda\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
# C:\Users\vicda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# C:\Users\vicda\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
tt_df = pd.DataFrame(text).rename(columns={0:'text'})

# %%
tt_df['Datas'] = [i['$date'].split('T')[0] for i in dts]

# %%
tt_df['User Location'] = [i['location'] for i in loc]

# %%
tt_df
# Out:
#                                                     text       Datas  \
# 0      @gerlainesouza @andeersonreis Efeitos da quare...  2020-04-11
# 1      RT @viiih2906: " A quarentena acabou, Já pode ...  2020-04-11
# 2      RT @AraciPatriota: Delegado Guerra se passou p...  2020-04-11
# 3      meu mood dps d tds esses shows da quarentena q...  2020-04-11
# 4      RT @josefucs: Perguntar não ofende: Quem é que...  2020-04-11
# ...                                                  ...         ...
# 99995  RT @gugachacra: A Suécia decidiu não isolar to...  2020-04-23
# 99996  Hoje me peguei desesperada, chorando compulsiv...  2020-04-23
# 99997  RT @hamylle1: culpem a quarentena rsrsrs #tikt...  2020-04-23
# 99998  RT @GFiuza_Oficial: As declarações de Lula e D...  2020-04-23
# 99999  Um vereador de minha cidade mostrando as falca...  2020-04-23
#
#                         User Location
# 0                           Recife,PE
# 1          na minha casa q fica no rj
# ...

# %%
index = [ind for ind,text in zip(tt_df.index,tt_df['text']) if 'quarentena' in text.lower().split() or 'confinamento' in text.lower().split()]
qua_len = len(index)
quar_conf = tt_df.iloc[index]

# %%
index = [ind for ind,text in zip(tt_df.index,tt_df['text']) if 'covid' in text.lower().split() or 'covid-19' in text.lower().split() or 'covid19' in text.lower().split() or 'coronavirus' in text.lower().split() or 'coronavírus' in text.lower().split() or 'corona' in text.lower().split()]
cor_len = len(index)
cor = tt_df.iloc[index]

# %%
index = [ind for ind,text in zip(tt_df.index,tt_df['text']) if 'aglomeração' in text.lower().split() or 'aglomerações' in text.lower().split()]
agl_len = len(index)
aglom = tt_df.iloc[index]

# %%
index = [ind for ind,text in zip(tt_df.index,tt_df['text']) if ('distanciamento','social') in nltk.bigrams(text.lower().split())]
dis_len = len(index)
dist_social = tt_df.iloc[index]

# %%
index = [ind for ind,text in zip(tt_df.index,tt_df['text']) if 'hidroxicloroquina' in text.lower().split() or 'cloroqouina' in text.lower().split()]
hid_len = len(index)
hidroxi_cloro = tt_df.iloc[index]

# %% [markdown]
# ### Training Model

# %%
#Sentiment Analysis in Português and English

base_path = 'c:/Users/vicda/Documents/ReLi-Lex'
train = []
wordsPT = []
wordsPT_sentiments = []

files = [os.path.join(base_path, f) for f in os.listdir(base_path)]

for file in files:
    t = 1 if '_Positivos' in file else -1
    with open(file, 'r') as content_file:
        content = content_file.read()
        all = re.findall('\[.*?\]',content)
        for w in all:
            wordsPT.append((w[1:-1]))
            wordsPT_sentiments.append(t)
            train.append((w[1:-1], t))

cl = NaiveBayesClassifier(train)

# %%
def clean_tweet(tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %% [markdown]
# ### Sentiment Analysis with TextBlob

# %%
def sentiment(tweet):
    
    polarity = 0
    
    #blob = TextBlob(tweet, classifier=cl)
    blob = TextBlob(clean_tweet(tweet), classifier=cl) #Clean Tweets
    
    for s in blob.sentences:
        polarity = s.classify() + polarity
    
    if polarity > 0:
        return 1
    elif polarity < 0:
        return -1
    else:
        return 0

# %%
def analize_sentimentEN(tweet):
    
    analysis = TextBlob(tweet)
    
    if analysis.detect_language() != 'en':
        analysis = TextBlob(str(analysis.translate(to='en')))
        time.sleep(0.5)    
        
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
#tweets_df['SA'] = np.array([ analize_sentimentEN(tweet) for tweet in tweets_df['Tweet'] ]) #English Dictionary

# %%
tt_df_copy = tt_df

# %%
# PARA FAZER ANÁLISE DE SUBCONJUNTOS, MANTER OS RESTANTES COMENTADOS

#tt_df = tt_df_copy
#tt_df = quar_conf
#tt_df = cor
#tt_df = aglom
tt_df = dist_social
#tt_df = hidroxi_cloro

# %%
tt_df['SA TextBlob'] = np.array([ sentiment(tweet) for tweet in tt_df['text'] ]) #Portuguese Dictionary
# Out:
# C:\Users\vicda\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Results of Sentiment Analysis

# %%
#Sentiment Analysis Results
pos_tweets = [ tweet for index, tweet in zip(tt_df.index,tt_df['text']) if tt_df['SA TextBlob'][index] > 0]
neg_tweets = [ tweet for index, tweet in zip(tt_df.index,tt_df['text']) if tt_df['SA TextBlob'][index] < 0]

# %%
print("Porcentagem de Tweets Positivos: {}%".format(len(pos_tweets)*100/len(tt_df['text'])))
print("Porcentagem de Tweets Negativos: {}%".format(len(neg_tweets)*100/len(tt_df['text'])))
# Out:
# Porcentagem de Tweets Positivos: 71.7479674796748%
# Porcentagem de Tweets Negativos: 28.252032520325205%

# %%
sentiments = ['Positivos', 'Negativos']
percents = [len(pos_tweets), len(neg_tweets)]

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Quarentena, Confinamento')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Coronavírus, Corona, Covid, Covid-19, Covid19')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Aglomeração, Aglomerações')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Distanciamento Social')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Hidroxicloroquina, Cloroquina')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %% [markdown]
# ### Word Cloud

# %%
stopwords= set(STOPWORDS)

new_words = []
with open("stopwords_portuguese.txt", 'r',encoding='utf-8') as f:
    [new_words.append(word) for line in f for word in line.split()]

new_stopwords = stopwords.union(new_words)

# %%
words = ' '.join(tt_df['text'])
words_clean = " ".join([word for word in words.split()
                            if 'https' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

# %%
from imageio import imread
import warnings

warnings.simplefilter('ignore')

#twitter_mask = imread('brasil_mask.png')
plt.figure(figsize=(20,10))
wc = WordCloud(min_font_size=10, 
               max_font_size=300, 
               background_color='white', 
               mode="RGB",
               stopwords=new_stopwords,
               collocations=False,
               width=2000, 
               height=1000,
               normalize_plurals= True).generate(words_clean)

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Time Series

# %%
#Tweets per Day
data = tt_df

data['Date'] = pd.to_datetime(data['Datas']).apply(lambda x: x.date())

tlen = pd.Series(data['Date'].value_counts(), index=data['Date'])
tlen.plot(figsize=(16,4), color='r');

# %% [markdown]
# # Twitter Setiments Analisys with NLTK

# %% [markdown]
# ### Training Model

# %%
vectorizer = CountVectorizer(analyzer="word")
freq_tweets = vectorizer.fit_transform(wordsPT)
modelo = MultinomialNB()
modelo.fit(freq_tweets,wordsPT_sentiments);

# %% [markdown]
# ### Sentiment Analisys

# %%
# PARA FAZER ANÁLISE DE SUBCONJUNTOS, MANTER OS RESTANTES COMENTADOS

#tt_df = tt_df_copy
#tt_df = quar_conf
#tt_df = cor
#tt_df = aglom
tt_df = dist_social
#tt_df = hidroxi_cloro

# %%
tweetsarray = []

for tw in tt_df['text']:
    text = clean_tweet(tw)
    tweetsarray.append(text)

# %%
predictionData = vectorizer.transform(tt_df['text'])
tt_df['SA NLTK'] = modelo.predict(predictionData)
# Out:
# C:\Users\vicda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Results of Sentiment Analysis

# %%
#Sentiment Analysis Results
pos_tweets = [ tweet for index, tweet in zip(tt_df.index,tt_df['text']) if tt_df['SA NLTK'][index] > 0]
neg_tweets = [ tweet for index, tweet in zip(tt_df.index,tt_df['text']) if tt_df['SA NLTK'][index] < 0]

# %%
print("Porcentagem de Tweets Positivos: {}%".format(len(pos_tweets)*100/len(tt_df['text'])))
print("Porcentagem de Tweets Negativos: {}%".format(len(neg_tweets)*100/len(tt_df['text'])))
# Out:
# Porcentagem de Tweets Positivos: 97.35772357723577%
# Porcentagem de Tweets Negativos: 2.6422764227642275%

# %%
sentiments = ['Positivos', 'Negativos']
percents = [len(pos_tweets), len(neg_tweets)]

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Quarentena, Confinamento')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Coronavírus, Corona, Covid, Covid-19, Covid19')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Aglomeração, Aglomerações')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Distanciamento Social')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %%
pie_chart = pd.Series(percents, index=sentiments, name='Sentimentos Hidroxicloroquina, Cloroquina')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6),startangle=-30);

# %% [markdown]
# ### Map of Tweets

# %%
geolocator = Nominatim(user_agent="TweeterSentiments")

latitude = []
longitude = []

for user_location in tt_df['User Location']:
    try:
        location = geolocator.geocode(user_location)
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    except:
        continue

# %%
coordenadas = np.column_stack((latitude, longitude))

mapa = folium.Map(location=[-15.788497,-47.879873],zoom_start=4.)

mapa.add_child(plugins.HeatMap(coordenadas))
mapa.save('lula-bolsonaro.html')
mapa
